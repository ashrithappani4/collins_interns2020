# %%
import pandas as pd

# %%
a=pd.read_csv("kd.csv")

# %%
a.describe()
# Out:
#             version   size(bytes)      downloads   discussions         views  \
# count  18518.000000  1.851800e+04   18518.000000  18518.000000  1.851800e+04
# mean       5.460471  4.204281e+09     394.869424      0.287882  3.083455e+03
# std       23.842488  4.230264e+11    2673.503306      1.705490  2.792698e+04
# min        1.000000  2.200000e+01       0.000000      0.000000  2.000000e+00
# 25%        1.000000  4.013425e+04       6.000000      0.000000  1.240000e+02
# 50%        1.000000  1.101386e+06      21.000000      0.000000  3.270000e+02
# 75%        1.000000  4.472701e+07      98.000000      0.000000  9.720000e+02
# max      370.000000  5.736049e+13  131731.000000     95.000000  3.052086e+06
#
#               likes       kernels
# count  18518.000000  18518.000000
# mean       9.816233      6.004752
# std       62.888877     56.726649
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# ...

# %%
a.head()
# Out:
#                              ref                        title  \
# 0        mlg-ulb/creditcardfraud  Credit Card Fraud Detection
# 1       tmdb/tmdb-movie-metadata      TMDB 5000 Movie Dataset
# 2             hugomathien/soccer     European Soccer Database
# 3  lava18/google-play-store-apps       Google Play Store Apps
# 4          zynicide/wine-reviews                 Wine Reviews
#
#                                             subtitle  \
# 0  Anonymized credit card transactions labeled as...
# 1                Metadata on ~5,000 movies from TMDb
# 2  25k+ matches, players & teams attributes for E...
# 3  Web scraped data of 10k Play Store apps for an...
# 4  130k wine reviews with variety, location, wine...
#
#                         creator  \
# 0  Machine Learning Group - ULB
# 1     The Movie Database (TMDb)
# 2                  Hugo Mathien
# 3                 Lavanya Gupta
# 4                    zackthoutt
#
#                                          description  version  \
# ...

# %%
a.head(13)
# Out:
#                                                   ref  \
# 0                             mlg-ulb/creditcardfraud
# 1                            tmdb/tmdb-movie-metadata
# 2                                  hugomathien/soccer
# 3                       lava18/google-play-store-apps
# 4                               zynicide/wine-reviews
# 5                            ronitf/heart-disease-uci
# 6                              unsdsn/world-happiness
# 7                                          uciml/iris
# 8                     wendykan/lending-club-loan-data
# 9                  uciml/breast-cancer-wisconsin-data
# 10               uciml/pima-indians-diabetes-database
# 11                              mehdidag/black-friday
# 12  russellyates88/suicide-rates-overview-1985-to-...
#
#                                             title  \
# 0                     Credit Card Fraud Detection
# 1                         TMDB 5000 Movie Dataset
# 2                        European Soccer Database
# ...

# %%
a.tail(9)
# Out:
#                                      ref                  title  \
# 18509       alexfraze/popular-embeddings     popular_embeddings
# 18510               zefangzhou/752754217                 089030
# 18511                  zefangzhou/t08894                 t08894
# 18512  nguyentranthanhphuc/eiu-220-95448          EIU_220_95448
# 18513               charalambos/sample-2               sample 2
# 18514                zefangzhou/zfsouyou               zfsouyou
# 18515                  zefangzhou/089271                 089271
# 18516  bettinajohn/python-ml-ch03-images  Python_ML_Ch03_images
# 18517               pramod722445/abcde16                abcde16
#
#                                                 subtitle  \
# 18509                                                NaN
# 18510                                                NaN
# 18511                                                NaN
# 18512                    bert-vanila-cont-from-220-95734
# ...

# %%
a.tail()
# Out:
#                                      ref                  title  \
# 18513               charalambos/sample-2               sample 2
# 18514                zefangzhou/zfsouyou               zfsouyou
# 18515                  zefangzhou/089271                 089271
# 18516  bettinajohn/python-ml-ch03-images  Python_ML_Ch03_images
# 18517               pramod722445/abcde16                abcde16
#
#                                                 subtitle  \
# 18513                                                NaN
# 18514                                                NaN
# 18515                                                NaN
# 18516  Images for WIDS-Atx presentation on Chapter 3 ...
# 18517                                                NaN
#
#                     creator  \
# 18513  Charalambos Stamatis
# 18514                  fang
# 18515                  fang
# 18516               Bettina
# 18517                pramod
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18518 entries, 0 to 18517
# Data columns (total 16 columns):
# ref             18518 non-null object
# title           18518 non-null object
# subtitle        8012 non-null object
# creator         18515 non-null object
# description     18518 non-null object
# version         18518 non-null int64
# keywords        5677 non-null object
# last_updated    18518 non-null object
# license_name    18518 non-null object
# size            18518 non-null object
# size(bytes)     18518 non-null int64
# downloads       18518 non-null int64
# discussions     18518 non-null int64
# views           18518 non-null int64
# likes           18518 non-null int64
# kernels         18518 non-null int64
# dtypes: int64(7), object(9)
# memory usage: 2.3+ MB

# %%
a.dtypes
# Out:
# ref             object
# title           object
# subtitle        object
# creator         object
# description     object
# version          int64
# keywords        object
# last_updated    object
# license_name    object
# size            object
# size(bytes)      int64
# downloads        int64
# discussions      int64
# views            int64
# likes            int64
# kernels          int64
# dtype: object

# %%
a.sort_values("version")
# Out:
#                                                      ref  \
# 9258                          melodydreamj/imagenet-file
# 11966                 sachin619/got-battle-of-blackwater
# 11969  msbrvamsi/population-country-wise-from-since-2...
# 11970                  kuroski/medicalappointmentnoshown
# 11971                     thaikeras/vsb-wavelet-denoised
# ...                                                  ...
# 4579   theworldbank/contributions-to-financial-interm...
# 12525      theworldbank/ibrd-summary-of-allocable-income
# 8548   theworldbank/commercial-credit-exposure-by-cou...
# 11499  theworldbank/ida-voting-power-of-member-countries
# 10111         theworldbank/miga-summary-income-statement
#
#                                                    title  \
# 9258                                       imageNet_file
# 11966                           GOT_battle_of_blackwater
# 11969       Population country wise since 2002 till 2016
# ...

# %%
a.sort_values("version").head(10)
# Out:
#                                                      ref  \
# 9258                          melodydreamj/imagenet-file
# 11966                 sachin619/got-battle-of-blackwater
# 11969  msbrvamsi/population-country-wise-from-since-2...
# 11970                  kuroski/medicalappointmentnoshown
# 11971                     thaikeras/vsb-wavelet-denoised
# 11972    isamuisozaki/roughly-one-quarter-of-openwebtext
# 11973                                ykatayama/180111-01
# 11977                   idasorndal/42156-english-website
# 11978                                  daniel012/pokemon
# 11979                                adri91186/extradata
#
#                                               title  \
# 9258                                  imageNet_file
# 11966                      GOT_battle_of_blackwater
# 11969  Population country wise since 2002 till 2016
# 11970                  medical-appointment-no-shown
# 11971                          VSB_Wavelet_Denoised
# ...

# %%
a.sort_values("downloads",ascending=False).head()
# Out:
#                              ref                        title  \
# 0        mlg-ulb/creditcardfraud  Credit Card Fraud Detection
# 1       tmdb/tmdb-movie-metadata      TMDB 5000 Movie Dataset
# 2             hugomathien/soccer     European Soccer Database
# 3  lava18/google-play-store-apps       Google Play Store Apps
# 4          zynicide/wine-reviews                 Wine Reviews
#
#                                             subtitle  \
# 0  Anonymized credit card transactions labeled as...
# 1                Metadata on ~5,000 movies from TMDb
# 2  25k+ matches, players & teams attributes for E...
# 3  Web scraped data of 10k Play Store apps for an...
# 4  130k wine reviews with variety, location, wine...
#
#                         creator  \
# 0  Machine Learning Group - ULB
# 1     The Movie Database (TMDb)
# 2                  Hugo Mathien
# 3                 Lavanya Gupta
# 4                    zackthoutt
#
#                                          description  version  \
# ...

# %%
a.sort_values("discussions",inplace=False).head()
# Out:
#                                        ref                   title  \
# 9258            melodydreamj/imagenet-file           imageNet_file
# 12322  rajesh289766/train-outliers-removed  train_outliers_removed
# 12323                sihaodi/lgbm-seed-666           lgbm seed 666
# 12324                      tanmayjk/yammer      User Drop Analysis
# 12325   pankeshpatel/handling-missing-data   handling missing data
#
#                                                 subtitle        creator  \
# 9258                                                 NaN       june lee
# 12322                                                NaN         RAJESH
# 12323                                                NaN       sihao di
# 12324  Analysis of drop in User engagement on an appl...    Tanmay Jain
# 12325                                                NaN  Pankesh Patel
#
#                                              description  version keywords  \
# ...

# %%
a.ref
# Out:
# 9258                       melodydreamj/imagenet-file
# 12322             rajesh289766/train-outliers-removed
# 12323                           sihaodi/lgbm-seed-666
# 12324                                 tanmayjk/yammer
# 12325              pankeshpatel/handling-missing-data
#                              ...
# 0                             mlg-ulb/creditcardfraud
# 5                            ronitf/heart-disease-uci
# 102      kiva/data-science-for-good-kiva-crowdfunding
# 1                            tmdb/tmdb-movie-metadata
# 2                                  hugomathien/soccer
# Name: ref, Length: 18518, dtype: object

# %%
a.ref.tail()
# Out:
# 0                           mlg-ulb/creditcardfraud
# 5                          ronitf/heart-disease-uci
# 102    kiva/data-science-for-good-kiva-crowdfunding
# 1                          tmdb/tmdb-movie-metadata
# 2                                hugomathien/soccer
# Name: ref, dtype: object

# %%
a["version"].value_counts()
# Out:
# 1      14194
# 2       1638
# 3        653
# 4        356
# 5        178
#        ...
# 296        1
# 93         1
# 205        1
# 265        1
# 220        1
# Name: version, Length: 184, dtype: int64

# %%
a.nunique()
# Out:
# ref             18518
# title           17681
# subtitle         6836
# creator         10034
# description     17739
# version           184
# keywords         2944
# last_updated    18508
# license_name       26
# size             2231
# size(bytes)     16683
# downloads        1801
# discussions        39
# views            4355
# likes             309
# kernels           236
# dtype: int64

# %%
a["version"].nunique()
# Out:
# 184

# %%
a[["version","downloads"]].nunique()
# Out:
# version       184
# downloads    1801
# dtype: int64

# %%
a["ref"].dtype
# Out:
# dtype('O')

# %%
n=a["version"].isnull()
n
# Out:
# 9258     False
# 12322    False
# 12323    False
# 12324    False
# 12325    False
#          ...
# 0        False
# 5        False
# 102      False
# 1        False
# 2        False
# Name: version, Length: 18518, dtype: bool
